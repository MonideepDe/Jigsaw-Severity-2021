# %%
import pandas as pd
import numpy as np

# %%
scores_df = pd.read_csv('../data/scores/raw_val_scores.csv', index_col=0)
print(scores_df)
# Out:
#        less_rob_base_model_1  less_rob_base_model_2  less_rob_base_model_3  \
# 0                   0.474884               0.480915               0.428328
# 1                   0.181850               0.177166               0.228931
# 2                   0.380824               0.342863               0.342613
# 3                   0.629606               0.527417               0.437302
# 4                   0.351183               0.368600               0.343023
# ...                      ...                    ...                    ...
# 30103               0.188918               0.181861               0.254873
# 30104               0.188918               0.181861               0.254873
# 30105               0.398503               0.370842               0.396344
# 30106               0.398503               0.370842               0.396344
# 30107               0.398503               0.370842               0.396344
#
# ...
